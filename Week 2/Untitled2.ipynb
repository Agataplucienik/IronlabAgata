# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\agata\Downloads\attention.csv")
df = df.drop('Unnamed: 0', axis=1)

# %%
df.head()
# Out:
#    subject attention  solutions  score
# 0        1   divided          1    2.0
# 1        2   divided          1    3.0
# 2        3   divided          1    3.0
# 3        4   divided          1    5.0
# 4        5   divided          1    4.0

# %%
grouped_score=df.groupby(['attention'])['score'].mean()
ratio=grouped_score["focused"]/grouped_score["divided"]

# %%
df = df.join(
    df.groupby('solutions')[['score']]
        .transform('mean')  # Calculate the mean for each group
        .rename(columns='mean {} for the area'.format)  # Rename columns 
)

# %%
result=df["solutions"][-1:]

# %%
result
# Out:
# 59    3
# Name: solutions, dtype: int64

# %%
''''Report the top 10 subjects ranked by the score in descending order. If there are ties in the scores, the subjects should be sorted by subject ID in ascending order. Reset indexes before returning the report.
Note: beware that a subject can appear more than once in the dat'''
# Out:
# "'Report the top 10 subjects ranked by the score in descending order. If there are ties in the scores, the subjects should be sorted by subject ID in ascending order. Reset indexes before returning the report.\nNote: beware that a subject can appear more than once in the dat"

# %%
df.groupby(['subject'])['score'].mean()
# Out:
# subject
# 1     4.333333
# 2     4.000000
# 3     4.666667
# 4     5.666667
# 5     5.666667
# 6     5.333333
# 7     5.166667
# 8     6.666667
# 9     4.000000
# 10    5.666667
# 11    5.666667
# 12    8.333333
# 13    6.666667
# 14    7.666667
# 15    7.666667
# 16    7.000000
# 17    6.666667
# 18    7.000000
# 19    5.666667
# 20    5.666667
# Name: score, dtype: float64

# %%
df
# Out:
#     subject attention  solutions  score  mean score for the area
# 0         1   divided          1    2.0                    5.350
# 1         2   divided          1    3.0                    5.350
# 2         3   divided          1    3.0                    5.350
# 3         4   divided          1    5.0                    5.350
# 4         5   divided          1    4.0                    5.350
# 5         6   divided          1    5.0                    5.350
# 6         7   divided          1    5.0                    5.350
# 7         8   divided          1    5.0                    5.350
# 8         9   divided          1    2.0                    5.350
# 9        10   divided          1    6.0                    5.350
# 10       11   focused          1    6.0                    5.350
# 11       12   focused          1    8.0                    5.350
# 12       13   focused          1    6.0                    5.350
# ...
