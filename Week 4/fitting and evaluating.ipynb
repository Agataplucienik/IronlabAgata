# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\agata\Downloads\marketing_customer_analysis_clean.csv")

# %%
df.head()
# Out:
#    unnamed:_0 customer       state  customer_lifetime_value response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    coverage education effective_to_date employmentstatus gender  ...  \
# 0     Basic   College        2011-02-18         Employed      M  ...
# 1     Basic   College        2011-01-18       Unemployed      F  ...
# 2     Basic  Bachelor        2011-02-10         Employed      M  ...
# 3  Extended   College        2011-01-11         Employed      M  ...
# 4   Premium  Bachelor        2011-01-17    Medical Leave      F  ...
#
#    number_of_policies     policy_type        policy  renew_offer_type  \
# ...

# %%
df=df.select_dtypes(include="number")

# %%
y=df[["total_claim_amount"]]

# %%
y
# Out:
#        total_claim_amount
# 0              292.800000
# 1              744.924331
# 2              480.000000
# 3              484.013411
# 4              707.925645
# ...                   ...
# 10905         1214.400000
# 10906          273.018929
# 10907          381.306996
# 10908          618.288849
# 10909         1021.719397
#
# [10910 rows x 1 columns]

# %%
X=df.drop("total_claim_amount", axis=1)

# %%
X
# Out:
#        unnamed:_0  customer_lifetime_value  income  monthly_premium_auto  \
# 0               0              4809.216960   48029                    61
# 1               1              2228.525238       0                    64
# 2               2             14947.917300   22139                   100
# 3               3             22332.439460   49078                    97
# 4               4              9025.067525   23675                   117
# ...           ...                      ...     ...                   ...
# 10905       10905             15563.369440       0                   253
# 10906       10906              5259.444853   61146                    65
# 10907       10907             23893.304100   39837                   201
# 10908       10908             11971.977650   64195                   158
# 10909       10909              6857.519928       0                   101
#
#        months_since_last_claim  months_since_policy_inception  \
# ...

# %%
X
# Out:
# array([[0.00000000e+00],
#        [4.80921696e+03],
#        [4.80290000e+04],
#        ...,
#        [0.00000000e+00],
#        [3.00000000e+00],
#        [1.00000000e+00]])

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression

# %%
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train
# Out:
#       unnamed:_0  customer_lifetime_value  income  monthly_premium_auto  \
# 7722        7722              2903.939763   67763                    73
# 6888        6888              7317.014254   24083                    63
# 675          675              5568.889245   53295                    70
# 4098        4098              3451.102440       0                   104
# 4518        4518              2402.172069   43246                    62
# ...          ...                      ...     ...                   ...
# 5734        5734              3810.238281       0                   108
# 5191        5191              3815.851163   38651                    98
# 5390        5390              7850.590399       0                    69
# 860          860              4974.235309       0                    70
# 7270        7270             38055.209530       0                   115
#
#       months_since_last_claim  months_since_policy_inception  \
# ...

# %%
y_train
# Out:
#       total_claim_amount
# 7722           59.861963
# 6888          340.453606
# 675           250.423844
# 4098          499.200000
# 4518           52.435202
# ...                  ...
# 5734          777.600000
# 5191          470.400000
# 5390          331.200000
# 860           336.000000
# 7270          552.000000
#
# [7637 rows x 1 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scale= StandardScaler()

# %%
scale.fit(X_train)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
transformed_train_X=scale.transform(X_train)

# %%
transformed_train_X
# Out:
# array([[ 0.71091459, -0.73657986,  0.99254463, ...,  0.69223164,
#         -0.82829562, -0.92587639],
#        [ 0.44649715, -0.10293065, -0.44663014, ...,  0.69223164,
#         -0.41009559, -0.92587639],
#        [-1.52331765, -0.35393435,  0.51585093, ..., -0.43754304,
#          2.0991046 , -0.92587639],
#        ...,
#        [-0.02843969, -0.02631737, -1.2401202 , ..., -0.43754304,
#         -0.41009559,  1.08005779],
#        [-1.4646639 , -0.43931745, -1.2401202 , ..., -0.43754304,
#          0.00810444,  1.08005779],
#        [ 0.56760922,  4.31059854, -1.2401202 , ..., -0.43754304,
#         -0.41009559,  1.08005779]])

# %%
lm=LinearRegression()

# %%
model=lm.fit(transformed_train_X, y_train)

# %%
model.coef_
# Out:
# array([[  1.89711627,  -4.88084046, -99.91757533, 188.04026999,
#           2.764124  ,  -4.65570423,  -1.14006818,  -0.24668876,
#          -0.32341426]])

# %%
model.intercept_
# Out:
# array([435.43080381])

# %%
transformed_test_X=scale.transform(X_test)

# %%
y_pred=model.predict(transformed_test_X)

# %%
y_test
# Out:
#        total_claim_amount
# 4829           475.423848
# 5081           350.400000
# 5011           482.400000
# 4625           673.342650
# 3838           302.400000
# ...                   ...
# 9968           144.728404
# 5239            93.566940
# 10001          253.637853
# 4828           284.000172
# 10483          485.183645
#
# [3273 rows x 1 columns]

# %%
y_pred[:,0]
# Out:
# array([125.51860824, 351.47534057, 419.23245276, ..., 413.44484161,
#        187.28861341, 425.0999335 ])

# %%
from sklearn.metrics import mean_squared_error as mse

# %%
mse(y_test, y_pred)**0.5
# Out:
# 199.52115732228904

# %%
real_vs_pred = pd.DataFrame({'y_test': y_test["total_claim_amount"], 'y_pred':y_pred[:,0]})

# %%
real_vs_pred
# Out:
#            y_test      y_pred
# 4829   475.423848  125.518608
# 5081   350.400000  351.475341
# 5011   482.400000  419.232453
# 4625   673.342650  433.127283
# 3838   302.400000  155.341392
# ...           ...         ...
# 9968   144.728404  332.692517
# 5239    93.566940  743.404324
# 10001  253.637853  413.444842
# 4828   284.000172  187.288613
# 10483  485.183645  425.099933
#
# [3273 rows x 2 columns]

# %%
from sklearn.metrics import mean_absolute_error as mae

# %%
mae(y_test, y_pred)
# Out:
# 144.8518651401059

# %%
from sklearn.metrics import r2_score

# %%
r2=r2_score(y_test, y_pred)

# %%
r2
# Out:
# 0.5188400003599476

# %%
Adj_r2 = 1-(((1-r2)*(7637-1))/(7637-9-1))
Adj_r2
# Out:
# 0.5182722227282759

# %%
import statsmodels.api as sm

X_train_const = sm.add_constant(X_train.to_numpy())

mode_l = sm.OLS(y_train, X_train_const).fit()
predictions_train = mode_l.predict(X_train_const)

X_test_const = sm.add_constant(X_test)
y_pred = mode_l.predict(X_test_const)
print_model = mode_l.summary()
print_model
# Out:
# C:\Users\agata\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:     total_claim_amount   R-squared:                       0.521
# Model:                            OLS   Adj. R-squared:                  0.520
# Method:                 Least Squares   F-statistic:                     921.5
# Date:                Wed, 08 Nov 2023   Prob (F-statistic):               0.00
# Time:                        15:31:34   Log-Likelihood:                -51434.
# No. Observations:                7637   AIC:                         1.029e+05
# Df Residuals:                    7627   BIC:                         1.030e+05
# Df Model:                           9
# Covariance Type:            nonrobust
# ...

# %%
# Check stationarity (perform differencing if necessary)
result = adfuller(df['Temperature'])
print(f'ADF Statistic: {result[0]}')
print(f'p-value: {result[1]}')

# If the data is not stationary, perform differencing
if result[1] > 0.05:
    df['Temperature_diff'] = df['Temperature'].diff().dropna()
else:
    df['Temperature_diff'] = df['Temperature']

# Split the data into training and testing sets
train_size = int(len(df) * 0.8)
train, test = df['Temperature_diff'][:train_size], df['Temperature_diff'][train_size:]

# Fit ARIMA model
model = ARIMA(train, order=(1, 1, 1))
fit_model = model.fit()

# Make predictions
predictions = fit_model.forecast(steps=len(test))

# Invert differencing to get original scale predictions
predictions_cumsum = predictions.cumsum()
predicted_values = df['Temperature'].iloc[train_size - 1] + predictions_cumsum

# Plot results
plt.plot(df['Year'], df['Temperature'], label='Actual Temperature')
plt.plot(df['Year'][train_size:], predicted_values, label='ARIMA Predictions', linestyle='--')
plt.title('ARIMA Temperature Prediction')
plt.xlabel('Year')
plt.ylabel('Temperature')
plt.legend()
plt.show()
