# %%
import numpy as np
import pandas as pd
import pickle
from sklearn import datasets # sklearn comes with some toy datasets to practice
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.metrics import silhouette_score

# %%
total=pd.read_csv("total.csv")

# %%
total=total[["energy", "loudness"]]
# Out:
#       Unnamed: 0  danceability  energy  key  loudness  mode  speechiness  \
# 0              0         0.894  0.7910    2    -4.699     1       0.1120
# 1              1         0.851  0.8060    4    -4.620     1       0.0787
# 2              2         0.778  0.8240   10    -5.892     0       0.0707
# 3              3         0.872  0.8720    1    -6.328     1       0.1390
# 4              4         0.762  0.7480    0    -4.150     0       0.0330
# ...          ...           ...     ...  ...       ...   ...          ...
# 1197        1197         0.190  0.0478    1   -20.941     1       0.0460
# 1198        1198         0.174  0.1810    8   -15.679     1       0.0385
# 1199        1199         0.394  0.3070    5   -18.869     1       0.0330
# 1200        1200         0.438  0.1290    4   -17.110     1       0.0452
# 1201        1201         0.349  0.0940    0   -22.316     1       0.0419
#
#       acousticness  instrumentalness  liveness  valence    tempo  \
# 0           0.0183          0.000000    0.0388   0.5830  105.018
# 1           0.1180          0.000002    0.1210   0.7870  118.999
# 2           0.2840          0.000000    0.4050   0.7580  100.024
# 3           0.0476          0.001120    0.0543   0.8090  116.948
# 4           0.0266          0.000000    0.3480   0.8510  110.009
# ...            ...               ...       ...      ...      ...
# 1197        0.9810          0.846000    0.1060   0.0803   68.600
# 1198        0.9890          0.009070    0.1050   0.0443  153.807
# 1199        0.5590          0.738000    0.2200   0.4350   71.408
# 1200        0.9650          0.797000    0.1710   0.8120  159.840
# 1201        0.9380          0.828000    0.0750   0.2280  124.764
#
#                 type                      id  \
# 0     audio_features  5rb9QrpfcKFHM1EUbSIurX
# 1     audio_features  1QV6tiMFM6fSOKOGLMHYYg
# 2     audio_features  3ZFTkvIE7kyPt6Nu3PEa7V
# 3     audio_features  2aI21FnmY7TJVKeMaoQZ0t
# 4     audio_features  6St9lR6dhV2tpCNVz7qfrS
# ...              ...                     ...
# 1197  audio_features  1MibzP0dzMkIKBp8MO14oN
# 1198  audio_features  4IRBAonqM9Gq1QyPuXyzRy
# 1199  audio_features  4IDrd1fYOcAOyZ97eKsXYS
# 1200  audio_features  2biF10SZJa8ytycndS2l4N
# 1201  audio_features  6AjAoIujyZaQmVZV0L9BmY
#
#                                        uri  \
# 0     spotify:track:5rb9QrpfcKFHM1EUbSIurX
# 1     spotify:track:1QV6tiMFM6fSOKOGLMHYYg
# 2     spotify:track:3ZFTkvIE7kyPt6Nu3PEa7V
# 3     spotify:track:2aI21FnmY7TJVKeMaoQZ0t
# 4     spotify:track:6St9lR6dhV2tpCNVz7qfrS
# ...                                    ...
# 1197  spotify:track:1MibzP0dzMkIKBp8MO14oN
# 1198  spotify:track:4IRBAonqM9Gq1QyPuXyzRy
# 1199  spotify:track:4IDrd1fYOcAOyZ97eKsXYS
# 1200  spotify:track:2biF10SZJa8ytycndS2l4N
# 1201  spotify:track:6AjAoIujyZaQmVZV0L9BmY
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/5rb9QrpfcKFH...
# 1     https://api.spotify.com/v1/tracks/1QV6tiMFM6fS...
# 2     https://api.spotify.com/v1/tracks/3ZFTkvIE7kyP...
# 3     https://api.spotify.com/v1/tracks/2aI21FnmY7TJ...
# 4     https://api.spotify.com/v1/tracks/6St9lR6dhV2t...
# ...                                                 ...
# 1197  https://api.spotify.com/v1/tracks/1MibzP0dzMkI...
# 1198  https://api.spotify.com/v1/tracks/4IRBAonqM9Gq...
# 1199  https://api.spotify.com/v1/tracks/4IDrd1fYOcAO...
# 1200  https://api.spotify.com/v1/tracks/2biF10SZJa8y...
# 1201  https://api.spotify.com/v1/tracks/6AjAoIujyZaQ...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/5rb9...       250373
# 1     https://api.spotify.com/v1/audio-analysis/1QV6...       237200
# 2     https://api.spotify.com/v1/audio-analysis/3ZFT...       218093
# 3     https://api.spotify.com/v1/audio-analysis/2aI2...       223080
# 4     https://api.spotify.com/v1/audio-analysis/6St9...       199027
# ...                                                 ...          ...
# 1197  https://api.spotify.com/v1/audio-analysis/1Mib...       274347
# 1198  https://api.spotify.com/v1/audio-analysis/4IRB...       284000
# 1199  https://api.spotify.com/v1/audio-analysis/4IDr...       304680
# 1200  https://api.spotify.com/v1/audio-analysis/2biF...       126840
# 1201  https://api.spotify.com/v1/audio-analysis/6AjA...       667973
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 1197               3
# 1198               3
# 1199               3
# 1200               4
# 1201               4
#
# [1202 rows x 19 columns]
